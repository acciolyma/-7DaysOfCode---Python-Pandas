# %% [markdown]
# <a href="https://colab.research.google.com/github/acciolyma/-7DaysOfCode---Python-Pandas/blob/main/Dia_4-Continuando_exploracao_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dia 1 - Importação de dados
#
# ---

# %%
import pandas as pd

# %% [markdown]
# ## Coletando dados

# %%
dados_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %% [markdown]
# ## Concatenando os DataFrames

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2        2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3        2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...                                ...                            ...
# 2258013  2020/05/05 19:51:06.059000000  2021/05/13 14:53:31.000000000
# 2258014  2020/05/05 19:51:06.135000000  2021/05/13 14:53:38.000000000
# 2258015  2020/05/05 19:51:06.164000000  2021/05/13 15:01:46.000000000
# 2258016  2020/06/09 11:54:02.669000000  2021/07/21 15:33:55.000000000
# 2258017  2020/06/09 11:54:02.852000000  2021/07/21 15:33:45.000000000
#
#          matricula_ou_siape             tipo_vinculo_usuario
# 0              2.008023e+09               ALUNO DE GRADUAÇÃO
# 1              2.008023e+09               ALUNO DE GRADUAÇÃO
# 2              2.008112e+09           ALUNO DE PÓS-GRADUAÇÃO
# 3              2.007211e+08               ALUNO DE GRADUAÇÃO
# 4              2.008023e+09               ALUNO DE GRADUAÇÃO
# ...                     ...                              ...
# 2258013        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIV
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# 3                          Biblioteca Central Zila Mamede         REGULAR
# 5                          Biblioteca Central Zila Mamede        ESPECIAL
# ...                                                   ...             ...
# 568580  Biblioteca Setorial do Núcleo de Educação da I...         REGULAR
# 568581                     Biblioteca Central Zila Mamede        ESPECIAL
# 568582                     Biblioteca Central Zila Mamede        ESPECIAL
# 568583                     Biblioteca Central Zila Mamede        ESPECIAL
# 568584                     Biblioteca Central Zila Mamede        ESPECIAL
#
#         localizacao  registro_sistema
# index
# 0               694                 1
# 1               688                 1
# 2               638                 1
# 3               616                 5
# 5               657                15
# ...             ...               ...
# 568580          951            268231
# 568581          997            268233
# 568582          987            268234
# 568583          764            268235
# 568584          962            268236
#
# [546237 rows x 7 columns]

# %% [markdown]
# ## Unindo os DataFrames

# %%
emprestimos_completo = emprestimos_biblioteca.merge(dados_exemplares)
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3        2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4        2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
# ...                                ...                            ...
# 2072517  2020/03/17 19:49:10.187000000  2020/12/03 08:12:20.000000000
# 2072518  2020/03/17 19:51:15.700000000  2021/01/07 11:16:28.000000000
# 2072519  2020/03/17 20:00:11.416000000  2021/08/30 13:29:44.000000000
# 2072520  2020/03/17 20:47:18.741000000                            NaN
# 2072521  2020/03/17 21:22:22.138000000  2021/07/26 15:05:20.000000000
#
#          matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0              2.008023e+09      ALUNO DE GRADUAÇÃO        13259
# 1              2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259
# 2              2.008023e+09      ALUNO DE GRADUAÇÃO        70865
# 3              2.008050e+09      ALUNO DE GRADUAÇÃO        70865
# 4              2.007226e+08      ALUNO DE GRADUAÇÃO        70865
# ...                     ...                     ...          ...
# 2072517        2.015011e+10      ALUNO DE GRADUAÇÃO       274820
# 2072518        2.019004e+10      ALUNO DE GRADUAÇÃO      1157915
# 2072519        2.019102e+10  ALUNO DE PÓS-GRADUAÇÃO      1317173
# 2072520        2.015013e+10      ALUNO DE GRADUAÇÃO       206073
# 2072521        2.020001e+10      ALUNO DE GRADUAÇÃO      1342535
#
#                    colecao                                         biblioteca  \
# 0        Acervo Circulante                     Biblioteca Central Zila Mamede
# 1        Acervo Circulante                     Biblioteca Central Zila Mamede
# 2        Acervo Circulante                     Biblioteca Central Zila Mamede
# 3        Acervo Circulante                     Biblioteca Central Zila Mamede
# 4        Acervo Circulante                     Biblioteca Central Zila Mamede
# ...                    ...                                                ...
# 2072517  Acervo Circulante                     Biblioteca Central Zila Mamede
# 2072518  Acervo Circulante                     Biblioteca Central Zila Mamede
# 2072519  Acervo Circulante  Biblioteca Setorial da Faculdade de Ciências d...
# 2072520  Acervo Circulante                     Biblioteca Central Zila Mamede
# 2072521  Acervo Circulante                     Biblioteca Central Zila Mamede
#
#         status_material  localizacao  registro_sistema
# 0               REGULAR          630              4225
# 1               REGULAR          630              4225
# 2               REGULAR          647             25009
# 3               REGULAR          647             25009
# 4               REGULAR          647             25009
# ...                 ...          ...               ...
# 2072517         REGULAR          676            120845
# 2072518         REGULAR          228            213248
# 2072519         REGULAR          784            255835
# 2072520         REGULAR          663             82178
# 2072521         REGULAR          355            174443
#
# [2072522 rows x 13 columns]

# %% [markdown]
# #Dia 2 - As primeiras manipulações

# %%
import pandas as pd

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema
# 0              4225
# 1              4225
# 2             25009
# 3             25009
# 4             25009

# %% [markdown]
# ## Atribuir a coluna com nomenclatura da CDU

# %%
CDU_lista = []
for CDU in emprestimos_completo['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_completo['CDU_geral'] = CDU_lista

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema           CDU_geral
# 0              4225  Ciências aplicadas
# 1              4225  Ciências aplicadas
# 2             25009  Ciências aplicadas
# 3             25009  Ciências aplicadas
# 4             25009  Ciências aplicadas

# %% [markdown]
# ## Excluir coluna "registro_sistema"

# %%
emprestimos_completo.drop(columns=['registro_sistema'],inplace=True)

# %% [markdown]
# ## Modificar tipo de dado da matrícula

# %%
emprestimos_completo['matricula_ou_siape'] = emprestimos_completo['matricula_ou_siape'].astype('string')

# %% [markdown]
# # Dia 3 - Explorando o Datetime dos dados

# %%
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas

# %% [markdown]
# ## Verificando a relação entre empréstimo e empréstimo de exemplar

# %%
emprestimos_completo['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 2010326     3
# 2014596     3
# 10240112    3
# 2422542     3
# 9690168     3
#            ..
# 2767562     1
# 2317930     1
# 2283256     1
# 2262867     1
# 2989061     1
# Name: count, Length: 2068724, dtype: int64

# %%
emprestimos_completo.loc[emprestimos_completo['id_emprestimo']==2560028]
# Out:
# Empty DataFrame
# Columns: [id_emprestimo, codigo_barras, data_renovacao, data_emprestimo, data_devolucao, matricula_ou_siape, tipo_vinculo_usuario, id_exemplar, colecao, biblioteca, status_material, localizacao, CDU_geral]
# Index: []

# %% [markdown]
# Note que o "id_emprestimo" é cada empréstimo realizado que pode ter 1 ou mais exemplares.
#
# Portando cada linha é o empréstimo de cada exemplar.

# %% [markdown]
# ### Quantos empréstimos foram realizados ao total?

# %%
emprestimos = len(emprestimos_completo['id_emprestimo'].drop_duplicates())
emprestimos
# Out:
# 2068724

# %% [markdown]
# ### Quantos exemplares foram emprestados ao total ?

# %%
exemplares = len(emprestimos_completo)
exemplares
# Out:
# 2072522

# %% [markdown]
# ## Quantidade de exemplares emprestados por ano

# %%
emprestimos_data = pd.DataFrame(emprestimos_completo['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                            data  quantidade
# 0       2017-04-20 21:07:44.036           3
# 1       2014-05-12 09:56:18.787           3
# 2       2015-05-05 20:37:19.551           3
# 3       2018-02-22 10:45:11.523           3
# 4       2014-01-28 14:49:50.505           3
# ...                         ...         ...
# 2068686 2012-04-11 10:12:20.960           1
# 2068687 2010-11-12 11:03:22.117           1
# 2068688 2015-09-15 14:26:08.838           1
# 2068689 2015-08-14 13:41:47.472           1
# 2068690 2020-03-17 21:22:22.138           1
#
# [2068691 rows x 2 columns]

# %%
emprestimos_por_ano = emprestimos_data.groupby(by=emprestimos_data.data.dt.year)['quantidade'].sum() # Select the 'quantidade' column for summation
emprestimos_por_ano = emprestimos_por_ano.to_frame().reset_index() # Convert the result to a DataFrame
emprestimos_por_ano.columns = ['ano', 'quantidade'] # Rename columns for clarity
emprestimos_por_ano
# Out:
#      ano  quantidade
# 0   2010      161394
# 1   2011      196390
# 2   2012      221365
# 3   2013      234749
# 4   2014      219189
# 5   2015      213582
# 6   2016      215900
# 7   2017      218462
# 8   2018      194080
# 9   2019      171801
# 10  2020       25610

# %% [markdown]
# ### Configurando tema dos gráficos

# %%
sns.set_theme(context='notebook',
              style='darkgrid',
              palette='deep',
              font_scale=1.3,
              rc={"figure.figsize":(15,8)})

# %%
ax = sns.lineplot(data=emprestimos_por_ano,x='ano',y='quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x', rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title('Quantidade de exemplares emprestados por ano'+'\n',size=20,loc='left',weight='bold')

ax=ax

# %% [markdown]
# Pode-ser perceber que desde 2013 os números de exemplares emprestados diminuindo, com uma queda bem grande em 2019.
#
# O ano de 2020 não pode ser avaliado igual, devido ao período da quantidade de dados.
#
# É importante a direção da biblioteca investigar o que está ocorrendo desde 2013 com os procedimentos realizados.
# Alguns questionamentos importantes que deve-se levar a direção, para que seja aprofundada em outra análise:
#
# * O número de alunos da universidade vem diminuindo?
# * Como está a pesquisa de satisfação dos usuários da biblioteca?
# * O acervo está atualizado?
# * Quais são as estratégias de marketing que a biblioteca está realizando?
# * O que ocorreu de diferente em 2017 em relação a 2016 e 2015 para que o número tenha se elevado?
# * E em 2019?

# %% [markdown]
# ## Quantos foram por cada mês ?

# %%
emprestimos_por_mes = emprestimos_data.groupby(by=emprestimos_data.data.dt.month)['quantidade'].sum() # Sum only the 'quantidade' column
emprestimos_por_mes.index.name = 'mes'
emprestimos_por_mes
# Out:
# mes
# 1      67514
# 2     210200
# 3     252185
# 4     208725
# 5     202530
# 6     138123
# 7     123790
# 8     232793
# 9     208234
# 10    188410
# 11    164222
# 12     75796
# Name: quantidade, dtype: int64

# %% [markdown]
# ### Modificando os números por nomes dos meses

# %%
dicionario_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}

# %%
emprestimos_por_mes.index = emprestimos_por_mes.index.map(dicionario_meses)

# %%
emprestimos_por_mes
# Out:
# mes
# Jan     67514
# Fev    210200
# Mar    252185
# Abr    208725
# Mai    202530
# Jun    138123
# Jul    123790
# Ago    232793
# Set    208234
# Out    188410
# Nov    164222
# Dez     75796
# Name: quantidade, dtype: int64

# %%
import seaborn as sns
import matplotlib.ticker as ticker

ax = sns.lineplot(data=emprestimos_por_mes, x=emprestimos_por_mes.index, y='quantidade') # Use the index as x-values
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x',rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title("Quantidade de exemplares emprestados por mês"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=265000,fontsize=18, ha='left',color='gray')

ax=ax
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-685769d03abf> in <cell line: 4>()
#       2 import matplotlib.ticker as ticker
#       3
# ----> 4 ax = sns.lineplot(data=emprestimos_por_mes, x=emprestimos_por_mes.index, y='quantidade') # Use the index as x-values
#       5 ax.set(xlabel=None,ylabel=None)
#       6 ax.tick_params(axis='x',rotation=30)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     478     errorbar = _deprecate_ci(errorbar, ci)
#     479
# --> 480     p = _LinePlotter(
#     481         data=data,
#     482         variables=dict(
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     213         )
#     214
# --> 215         super().__init__(data=data, variables=variables)
#     216
#     217         self.estimator = estimator
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      55     ):
#      56
# ---> 57         data = handle_data_source(data)
#      58         frame, names, ids = self._assign_variables(data, variables)
#      59
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in handle_data_source(data)
#     276     elif data is not None and not isinstance(data, Mapping):
#     277         err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278         raise TypeError(err)
#     279
#     280     return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'pandas.core.series.Series'>.

# %%
import seaborn as sns
import matplotlib.ticker as ticker

# Convert emprestimos_por_mes to a DataFrame if it's a Series
if not isinstance(emprestimos_por_mes, pd.DataFrame):
    emprestimos_por_mes = emprestimos_por_mes.to_frame()

ax = sns.lineplot(data=emprestimos_por_mes, x=emprestimos_por_mes.index, y='quantidade') # Use the index as x-values
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x',rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))

ax.set_title("Quantidade de exemplares emprestados por mês"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=265000,fontsize=18, ha='left',color='gray')

ax=ax

# %% [markdown]
# Pode-se visualizar que os meses com maiores números de exemplares emprestados foram em **março** e **agosto**.
#
# Por ser uma biblioteca universitária meses de férias como janeiro, julho e dezembro são os menores números.
#
# O que não é nada de novo, entretanto caso todos os colaboradores saírem de férias durante esse período não conseguiríamos manter todo o funcionamento da biblioteca.
#
# Principalmente com atividades de inventário que podem ocorrer anualmente ou de dois em dois anos e o melhor período seria de dezembro a janeiro.
#
# Então meses como maio, junho, outubro e novembro podem ser uma opção a ser considerada pela direção da biblioteca.
#
# Nota-se também a grande queda no mês de junho. Cabe aqui um alerta para se investigar mais, o que está ocorrendo e desenvolver estratégias e ações de marketing da biblioteca para que se aumente o número de exemplares emprestados.
#
# Como por exemplo: uma ação para que sejam realizados empréstimos de livros para a leitura nas férias de julho.

# %% [markdown]
# ## Qual é a quantidade de empréstimos por hora ao longo do dia ?

# %%
emprestimos_data.data
# Out:
# 0         2017-04-20 21:07:44.036
# 1         2014-05-12 09:56:18.787
# 2         2015-05-05 20:37:19.551
# 3         2018-02-22 10:45:11.523
# 4         2014-01-28 14:49:50.505
#                     ...
# 2068686   2012-04-11 10:12:20.960
# 2068687   2010-11-12 11:03:22.117
# 2068688   2015-09-15 14:26:08.838
# 2068689   2015-08-14 13:41:47.472
# 2068690   2020-03-17 21:22:22.138
# Name: data, Length: 2068691, dtype: datetime64[ns]

# %%
emprestimos_por_hora = emprestimos_data.groupby(by=emprestimos_data.data.dt.hour)['quantidade'].sum() # Sum the 'quantidade' column instead of the 'data' column
emprestimos_por_hora.index.name = 'horas'
emprestimos_por_hora = emprestimos_por_hora.reset_index()
emprestimos_por_hora
# Out:
#     horas  quantidade
# 0       0          17
# 1       6          14
# 2       7       18777
# 3       8      103416
# 4       9      131273
# 5      10      185839
# 6      11      180048
# 7      12      148754
# 8      13      126987
# 9      14      150876
# 10     15      166672
# 11     16      210655
# 12     17      185340
# 13     18      182520
# 14     19      102129
# 15     20      127716
# 16     21       51191
# 17     22         247
# 18     23          51

# %%
emprestimos_por_hora = emprestimos_por_hora.sort_values(ascending=True,by='quantidade')

# %%
ax = sns.barplot(data=emprestimos_por_hora,y='quantidade',x='horas',
                 palette='Blues',hue='quantidade',dodge=False)                  #Ordenar pela quantidade de exemplares emprestados
plt.legend([],[], frameon=False)                                                #Excluir a legenda do gráfico

ax.set(xlabel='Horário',ylabel=None)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
ax.set_title("Quantidade de exemplares emprestados por faixa horária"+"\n",size=20,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=225000,fontsize=18, ha='left',color='gray')
ax=ax

# %% [markdown]
# Através do gráfico é possível identificar que os períodos das 10 h e 16 h são os de maior pico no atendimento de empréstimos.
#
# Períodos do começo da manhã (entre 7h e 9) e da noite (entre 19h e 22) podem ser os melhores horários para que se realizem as demais atividades além do atendimento.

# %% [markdown]
# Dia 4 - Análise exploratória de dados e Variáveis categóricas
#
# Objetivo: Analisar a quantidade de empréstimos em uma biblioteca, considerando variáveis categóricas como tipo de vínculo, coleção, biblioteca e classificação CDU.
# - verificar valores únicos dentro da variável
# - entender qual é o público da biblioteca (a partir do tipo de vínculo)
# - ranquear coleções mais emprestadas
# - bibliotecas com mais ou menos quant de empréstimos
#
# - temas CDU mais emprestados (tabela frequência % de cada variável. crie uma função que gere a tabela com os valores)

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#             CDU_geral
# 0  Ciências aplicadas
# 1  Ciências aplicadas
#  'Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - \xadCERES\xad - Caicó'
#  'Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos'
#  'Biblioteca Setorial do Núcleo de Educação da Infância - NEI'
#  'Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz'
#  'Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz']
# ['Ciências aplicadas' 'Linguagem' 'Ciências sociais'
#  'Geografia. Biografia. História.' 'Matemática e ciências naturais'
#  'Religião' 'Generalidades' 'Filosofia e psicologia' 'Belas artes']

# %% [markdown]
# Fazendo Criando Função Tabela Frequência (mesma fórmula para geral)

# %% [markdown]
# Entendimento do Público da Biblioteca

# %%
# Para incluir tanto a quantidade quanto o percentual na função tabela_frequencia, você pode modificar a função para que ela retorne um DataFrame com essas duas colunas.

def tabela_frequencia(coluna):
  quantidade = coluna.value_counts()
  percentual = coluna.value_counts(normalize=True) * 100
  tabela_frequencia = pd.DataFrame({'Quantidade':quantidade,'Percentual (%)':percentual.round(2)})
  return tabela_frequencia.round(2)

tabela_frequencia_vinculo = tabela_frequencia(emprestimos_completo['tipo_vinculo_usuario'])
tabela_frequencia_vinculo
# Out:
#                                  Quantidade  Percentual (%)
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324           77.80
# ALUNO DE PÓS-GRADUAÇÃO               302541           14.60
# DOCENTE                               70981            3.42
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184            1.55
# ALUNO MÉDIO/TÉCNICO                   28029            1.35
# DOCENTE EXTERNO                       23949            1.16
# USUÁRIO EXTERNO                        2509            0.12
# OUTROS                                    5            0.00

# %% [markdown]
# O maior público da biblioteca são de fato os alunos de graduação com aproxidamente 78% o segundo maior público é o de pós graduação com aproximadamente 15%.
#
# Vale lembrar que esta é apenas uma métrica geral a partir dos exemplares emprestados.
#
# Possilvemente a maior diferença entre os percentuais dos dois anteriores é devido a dois pontos:
#
# Alunos de pós graduação, tem o maior enfoque em artigos científicos que são acessados através de bases de dados bibliográficas.
# A maior quantidade de alunos de graduação em comparação com os da pós na universidade.

# %% [markdown]
# Ranqueando Coleções Mais Emprestadas

# %%
# Gerando uma tabela de fequência e % para a variável colecao para identificar as mais populares entre os empréstimos
tabela_frequencia_colecao = tabela_frequencia(emprestimos_completo['colecao'])
tabela_frequencia_colecao
# Out:
#                                        Quantidade  Percentual (%)
# colecao
# Acervo Circulante                         2053120           99.06
# Multimeios                                   7954            0.38
# Monografias                                  4021            0.19
# Dissertações                                 2406            0.12
# Obras de Referência                          1954            0.09
# Publicações de Autores do RN                  866            0.04
# Publicações da UFRN                           764            0.04
# Teses                                         714            0.03
# Folhetos                                      271            0.01
# Necessidades Educacionais Específicas         130            0.01
# Trabalho Acadêmico                            115            0.01
# Eventos                                       101            0.00
# Coleção Mossoroense                            44            0.00
# Coleção Zila Mamede                            30            0.00
# Literatura de Cordel                           24            0.00
# Obras Raras                                     8            0.00

# %% [markdown]
# A principal coleção é a própria circulante o que se cria um alerta, pois está com 99% de todos os exemplares empréstados.
#
# Principalmente para as monografias, dissertações e teses que poderiam estar sendo mais consultadas para que haja um crescimento das discussões de pesquisa interna da instituição.
#
# Entretanto é importante verificar se esses documentos não estão disponíveis na coleção online e por este motivo não é emprestada fisicamente.
#
# As coleções: Coleção Mossoroense, Coleção Zila Mamede, Literatura de Cordel, Obras Raras devem ter uma atenção especial em entender a razão que estão com números tão pequenos de frequência.

# %% [markdown]
# Podem ser feitos eventos promovendo as categorias menos lidas.

# %% [markdown]
# Biblioteca com + e - Empréstimos

# %%
# Criando tabela para saber as bibliotecas que mais tiveram quantidade de emprestimos
tabela_frequencia_biblioteca = tabela_frequencia(emprestimos_completo['biblioteca'])
tabela_frequencia_biblioteca
# Out:
#                                                     Quantidade  Percentual (%)
# biblioteca
# Biblioteca Central Zila Mamede                         1426122           68.81
# Biblioteca Setorial do Centro Ciências da Saúde...      118614            5.72
# Biblioteca Setorial da Faculdade de Ciências da...       77609            3.74
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447            3.21
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478            2.97
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040            2.22
# Biblioteca Setorial do Centro de Ciências Human...       40744            1.97
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097            1.55
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089            1.40
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219            1.31
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923            1.30
# Biblioteca Setorial do Núcleo de Educação da In...       23656            1.14
# Biblioteca Setorial Prof. Ronaldo Xavier de Arr...       22749            1.10
# Biblioteca Setorial Pe. Jaime Diniz - Escola de...       21476            1.04
# Biblioteca Setorial do Departamento de Artes - ...       17099            0.83
# Biblioteca Setorial Prof. Leopoldo Nelson - ­Ce...       12900            0.62
# Biblioteca Setorial do Centro Ciências Sociais ...       10533            0.51
# Biblioteca Setorial Prof. Dr. Marcelo Bezerra d...        5057            0.24
# Biblioteca Setorial Prof. Horácio Nicolas Solim...        4098            0.20
# Biblioteca Setorial Moacyr de Góes - CE                   1036            0.05
# Biblioteca Setorial Árvore do Conhecimento - In...         919            0.04
# Biblioteca Setorial do Núcleo de Ensino Superio...         617            0.03

# %%
# Gerando uma tabela de fequência e % para a variável CDU_geral para identificar as mais populares entre os empréstimos
tabela_frequencia_CDU = tabela_frequencia(emprestimos_completo['CDU_geral'])
tabela_frequencia_CDU
# Out:
#                                  Quantidade  Percentual (%)
# CDU_geral
# Ciências aplicadas                  1425473           68.78
# Ciências sociais                     369536           17.83
# Matemática e ciências naturais        68744            3.32
# Generalidades                         62521            3.02
# Religião                              62295            3.01
# Filosofia e psicologia                60563            2.92
# Geografia. Biografia. História.        7989            0.39
# Belas artes                            7911            0.38
# Linguagem                              7490            0.36
